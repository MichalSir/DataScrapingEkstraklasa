# %%
import numpy as np
import pandas as pd
import datetime as dt
import dash
import plotly.express as px

# %%
Stats = pd.read_csv("Stats.csv", sep=";")
Summary = pd.read_csv("Summary.csv", sep=";")
Teams = pd.read_csv("Teams.csv", sep= ";")

# %%
Stats.head()
# Out:
#    ID  Kolejka                 Data          Zespol1-Nazwa  Zespol1-Bramki  \
# 0   0       30  2021-05-16 17:30:00  Jagiellonia Białystok               2
# 1   1       30  2021-05-16 17:30:00            Lech Poznań               1
# 2   2       30  2021-05-16 17:30:00         Legia Warszawa               1
# 3   3       30  2021-05-16 17:30:00          Piast Gliwice               2
# 4   4       30  2021-05-16 17:30:00         Pogoń Szczecin               1
#
#        Zespol2-Nazwa  Zespol2-Bramki  Zespol1-Posiadanie piłki  \
# 0      Lechia Gdańsk               1                        48
# 1      Górnik Zabrze               1                        55
# 2       Podbeskidzie               0                        63
# 3       Wisła Kraków               3                        55
# 4  Raków Częstochowa               3                        62
#
#    Zespol1-Strzały  Zespol1-Strzały celne  ...  Zespol2-Strzały celne  \
# 0                7                      5  ...                      7
# 1               15                      7  ...                      7
# 2               17                      5  ...                      3
# 3               20                      7  ...                      7
# 4               15                      3  ...                      5
#
#    Zespol2-Strzały niecelne  Zespol2-Strzały zablokowane  Zespol2-Ataki  \
# 0                         5                            0            120
# 1                         5                            4             94
# 2                        12                            0             86
# 3                         2                            0             48
# 4                         4                            0             72
#
#    Zespol2-Groźne ataki  Zespol2-Kartki  Zespol2-Faule  Zespol2-Rzuty wolne  \
# 0                    81               4             10                   12
# 1                    46               1              7                   13
# 2                    60               0             15                   12
# 3                    27               3             22                   17
# 4                    38               2             17                   13
#
#    Zespol2-Rzuty rożne  Zespol2-Spalone
# 0                    8                6
# 1                    6                1
# 2                    7                1
# 3                    2                3
# 4                    1                2
#
# [5 rows x 31 columns]

# %%
Goals = Summary[(Summary["Co"] == "Gol") & (Summary["Info"] != "samobój")].groupby(by=["Kto"])["Co"].count()

# %%
Goals
# Out:
# Kto
# /zawodnik-%C5%BD-udovi%C4%8Dic,144998    2
# /zawodnik-a-benedyczak,468254            3
# /zawodnik-a-fraczczak,43360              2
# /zawodnik-a-gorgon,35793                 4
# /zawodnik-a-johannsson,78577             2
#                                         ..
# M. Roginic                               2
# Muhamad Awad                             1
# Nika Kacharava                           1
# P. Wiśniewski                            1
# T. Alves                                 4
# Name: Co, Length: 203, dtype: int64
